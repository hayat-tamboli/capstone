# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./DiseaseOutbreaks/COVIDOutbreaks.csv",index_col = 0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 665 entries, 3 to 670
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     665 non-null    object
#  1   iso2        665 non-null    object
#  2   iso3        656 non-null    object
#  3   Year        665 non-null    int64
#  4   icd10n      665 non-null    object
#  5   icd103n     665 non-null    object
#  6   icd104n     665 non-null    object
#  7   icd10c      665 non-null    object
#  8   icd103c     665 non-null    object
#  9   icd104c     665 non-null    object
#  10  icd11c1     665 non-null    int64
#  11  icd11c2     665 non-null    object
#  12  icd11c3     665 non-null    object
#  13  icd11l1     665 non-null    object
#  14  icd11l2     665 non-null    object
#  15  icd11l3     665 non-null    object
#  16  Disease     665 non-null    object
#  17  DONs        665 non-null    object
#  18  Definition  665 non-null    object
# ...

# %%
df.shape
# Out:
# (665, 19)

# %%
df.tail(10)
# Out:
#           Country iso2 iso3  Year  \
# 661       Mayotte   YT  MYT  2020
# 662  South Africa   ZA  ZAF  2021
# 663  South Africa   ZA  ZAF  2022
# 664  South Africa   ZA  ZAF  2020
# 665        Zambia   ZM  ZMB  2020
# 666        Zambia   ZM  ZMB  2021
# 667        Zambia   ZM  ZMB  2022
# 668      Zimbabwe   ZW  ZWE  2020
# 669      Zimbabwe   ZW  ZWE  2021
# 670      Zimbabwe   ZW  ZWE  2022
#
#                                                 icd10n               icd103n  \
# 661  Provisional assignment of new diseases of unce...  Emergency use of U07
# 662  Provisional assignment of new diseases of unce...  Emergency use of U07
# 663  Provisional assignment of new diseases of unce...  Emergency use of U07
# 664  Provisional assignment of new diseases of unce...  Emergency use of U07
# 665  Provisional assignment of new diseases of unce...  Emergency use of U07
# 666  Provisional assignment of new diseases of unce...  Emergency use of U07
# ...

# %%
df.Disease.unique()
# Out:
# array(['COVID-19'], dtype=object)
